# %%
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

# %%
import os
os.environ['OPENAI_API_KEY'] = "sk-proj-Uy-waKz2HbqxdqyTb1gUhyDaG-O6oU0YRIUJ6cm9l-Bzdq1qMHWyepOgQFMMcf5k5mFT12ulF_T3BlbkFJvpi2Gl0L387W0bihNY8VG3gWMNZNQWveqAuN8b-HMw7ZXXxu-iHoay9yvVL9Iortqsq1gfISk"

# %%
pdfreader = PdfReader('Doctrine_of_bonafide_purchaser.pdf')

# %%
from typing_extensions import Concatenate

raw_text = ''

for i, page in enumerate(pdfreader.pages):
    content = page.extract_text()
    if content:
        raw_text +=  content

# %%
raw_text
# Out:
# "2024 INSC 540\nCivil Appeal No. 1573  of 20 23  Page 1 of 56 \n REPORTABLE  \nIN THE SUPREME COURT OF INDIA  \nCIVIL APPELLATE JURISDICTION  \n \nCIVIL APPEAL NO. 1573  OF 20 23 \n  \nKAUSHIK PREMKU MAR MISHRA  \n& ANR.                …APPELLANT(S)  \nVERSU S \nKANJI RAVARIA  \n@ KANJI & ANR.               …RESPONDENT(S)  \n                                 \nJ U D G M E N T  \n \nVIKRAM NATH, J.  \n \n1. “Law is the king of kings, nothing is mightier than \nlaw, by whose aid, even the weak may prevail \nover the strong.”  \nThe power structures of our society are such that \nthe weaker ones often find themselves exploited \nand oppressed by those who yield greater power. \nLand ownership is one such arena where we see \nthe swords of powerplay being sharpened with \ncontinued fraud, de ceit, and greed. While we \nshall deal with the facts of the present case in \ndetail later, it is a classic example of continued Civil Appeal No. 1573  of 20 23  Page 2 of 56 \n suffering faced by the common man owing to \nmala  fide intentions of the vendors who try to \ngain double -benefits, either by arm -twisting or \nthrough manipulation of the legal processes. \nSometimes, the misery of the litigant is deepened \nwhen such travesty of justice is prolonged for \ndecades. It is in cases like  these, the law comes \nto the aid of the weak. While adjudicating such \ncases, it is not just the lives and the properties of \nthe people that we are dealing with, but also their \ntrust in the legal system. I n cases like the one \nbefore us, it is not for us to just mechanically \nanalyse the contentious transactions but to also \nensure that injustice is remedied and nobody is \nbenefitted by their own wrongs. Justice knows no \nbias and thus, through its aid, even the  weak \nmay prevail over the strong.   \n2. This appeal by the plaintiff assails the \ncorrectness  of the judgment and order dated 9th \nJune, 2022 passed by the High Court of \nJudicature at Bombay , whereby the Second \nAppeal filed by the defendant no.2 (respondent \nno.1 herein) was allowed the judgment of the first \nAppellate  Court was set aside and that of the Civil Appeal No. 1573  of 20 23  Page 3 of 56 \n Trial Court dismissing the suit of the appellant \nwas maintained.  \n3. Respondent no.2 was the owner of Survey No.13 \nHissa No.1 measuring 3.40 Hectares situate in \nvillage Shel wali, Tehsil Palghar, District Thane, \nMaharashtra. Half of the total area which would \ncome to  1.70 Hectares on the western side is the \nsuit land purchased by the appellants. \nRemaining half was purchased by collaterals of \nthe appellants.  \n4. Relevant facts for appropriate adjudication of this \nappeal are as follows:  \n(a) Respondent no.2 herein executed a Sale Deed in \nfavour of appellant no.1 and his minor brother \nAmbrish Mishra (since deceased) on 02.12.1985 \nwith respect to suit land and the appellant  no.1, \nalong with his brother, was put into possession \nof the same.  \n(b) On the same date another Sale Deed was \nexecuted by the respondent no.2 in favour of \none Param Umakant Mishra and Sohardha \nJagdish Mishra (collaterals of the appellant s) for \nthe remaining half portion.  Civil Appeal No. 1573  of 20 23  Page 4 of 56 \n (c) On 05.12.1985 both the aforementioned Sale \nDeeds were presented for registration before the \nSub-Registrar , Palghar.  \n(d) The Sale Deed in favour of Param Mishra and \nSohardha Mishra was registered  and later  on \ntheir names were mutated in the revenue \nrecords. However, on account of deficiency in \nstamp duty,  the Sale Deed in favour of the \nappellant no.1 and his minor brother could not \nbe registered and remain ed pending for \nregistration before the Sub -Registrar.  As such \ntheir names could not be incorporated in the \nrevenue records and the name of the respondent \nno.2 continued to be recorded.  \n(e) It would be relevant to mention that in the Sale \nDeed it was mentioned that the appellant no.1 \nis aged 18 y ...

# %%
text_splitter  = CharacterTextSplitter(
    separator= "\n",
    chunk_size = 800,
    chunk_overlap = 200,
    length_function = len,)
texts = text_splitter.split_text(raw_text)

# %%
len(texts)
# Out:
# 100

# %%
embeddings = OpenAIEmbeddings()

# %%
document_search = FAISS.from_texts(texts, embeddings)

# %%
document_search

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
chain = load_qa_chain(OpenAI(), Chain_type = "stuff")
# Out:
# /var/folders/1r/p7hsg4h96mn2mn7xwtkmbb080000gn/T/ipykernel_29853/2095008666.py:1: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   chain = load_qa_chain(OpenAI(), Chain_type = "stuff")
# /var/folders/1r/p7hsg4h96mn2mn7xwtkmbb080000gn/T/ipykernel_29853/2095008666.py:1: LangChainDeprecationWarning: This class is deprecated. See the following migration guides for replacements based on `chain_type`:
# stuff: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain
# map_reduce: https://python.langchain.com/docs/versions/migrating_chains/map_reduce_chain
# refine: https://python.langchain.com/docs/versions/migrating_chains/refine_chain
# map_rerank: https://python.langchain.com/docs/versions/migrating_chains/map_rerank_docs_chain
#
# See also guides on retrieval and question-answering here: https://python.langchain.com/docs/how_to/#qa-with-rag
#   chain = load_qa_chain(OpenAI(), Chain_type = "stuff")
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 chain = load_qa_chain(OpenAI(), Chain_type = "stuff")
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain/chains/question_answering/chain.py:265, in load_qa_chain(llm, chain_type, verbose, callback_manager, **kwargs)
#     260 if chain_type not in loader_mapping:
#     261     raise ValueError(
#     262         f"Got unsupported chain type: {chain_type}. "
#     263         f"Should be one of {loader_mapping.keys()}"
#     264     )
# --> 265 return loader_mapping[chain_type](
#     266     llm, verbose=verbose, callback_manager=callback_manager, **kwargs
#     267 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain/chains/question_answering/chain.py:83, in _load_stuff_chain(llm, prompt, document_variable_name, verbose, callback_manager, callbacks, **kwargs)
#      75 llm_chain = LLMChain(
#      76     llm=llm,
#      77     prompt=_prompt,
#    (...)
#      80     callbacks=callbacks,
#      81 )
#      82 # TODO: document prompt
# ---> 83 return StuffDocumentsChain(
#      84     llm_chain=llm_chain,
#      85     document_variable_name=document_variable_name,
#      86     verbose=verbose,  # type: ignore[arg-type]
#      87     callback_manager=callback_manager,
#      88     callbacks=callbacks,
#      89     **kwargs,
#      90 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:216, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     214     warned = True
#     215     emit_warning()
# --> 216 return wrapped(self, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/langchain_core/load/serializable.py:125, in Serializable.__init__(self, *args, **kwargs)
#     123 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124     """"""
# --> 125     super().__init__(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pydantic/main.py:193, in BaseModel.__init__(self, **data)
#     191 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     192 __tracebackhide__ = True
# --> 193 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 1 validation error for StuffDocumentsChain
# Chain_type
#   Extra inputs are not permitted [type=extra_forbidden, input_value='stuff', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/extra_forbidden
